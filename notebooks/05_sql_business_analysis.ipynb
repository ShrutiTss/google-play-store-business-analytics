# %% [markdown]
# # SQL Business Analysis
#
# This notebook focuses on answering business questions using SQL. The cleaned Google Play Store dataset is imported into MySQL, and SQL queries are used to extract actionable insights that complement the Python-based exploratory data analysis.

# %% [markdown]
# ### Objectives
#
# - Import the cleaned dataset into MySQL.
# - Perform business analysis using SQL.
# - Practice real-world SQL concepts such as filtering, aggregation, grouping, sorting, subqueries, Common Table Expressions (CTEs), and window functions.
# - Generate insights that can later be integrated into the Power BI dashboard.
