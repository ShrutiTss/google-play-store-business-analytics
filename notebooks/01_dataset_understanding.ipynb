# %% [markdown]
# # Google Play Store Business Analytics Dashboard
#
# ## Phase 1: Getting Started with the Dataset
#
# ### Objective
#
# The purpose of this notebook is to perform an initial inspection of the Google Play Store dataset before any cleaning or analysis begins.
#
# The goals are to:
#
# - Load the dataset successfully
# - Understand its dimensions
# - Inspect the available columns
# - Identify data types
# - Detect any obvious data quality issues
# - Build a foundational understanding of the data
#
# No cleaning, transformations, or business analysis will be performed in this notebook.

# %% [markdown]
# ## Step 1: Import Required Libraries

# %%
import pandas as pd

# %% [markdown]
# ## Step 2: Load the Dataset
#
# In this step, we will load the Google Play Store dataset into a Pandas DataFrame.
#
# It allows us to efficiently inspect, manipulate, and analyze structured data.
#
# Here our goal is only to verify that the dataset loads successfully. No transformations or analysis will be performed yet.

# %%
# Load the dataset

df = pd.read_csv("../data/raw/Google-Playstore.csv")

# %%
# Display the first five rows

df.head()
# Out:
#                                             App Name  \
# 0                                            Gakondo
# 1                                Ampere Battery Info
# 2                                             Vibook
# 3  Smart City Trichy Public Service Vehicles 17UC...
# 4                                            GROW.me
#
#                        App Id       Category  Rating  Rating Count Installs  \
# 0         com.ishakwe.gakondo      Adventure     0.0           0.0      10+
# 1  com.webserveis.batteryinfo          Tools     4.4          64.0   5,000+
# 2        com.doantiepvien.crm   Productivity     0.0           0.0      50+
# 3     cst.stJoseph.ug17ucs548  Communication     5.0           5.0      10+
# 4        com.horodyski.grower          Tools     0.0           0.0     100+
#
#    Minimum Installs  Maximum Installs  Free  Price  ...  \
# 0              10.0                15  True    0.0  ...
# 1            5000.0              7662  True    0.0  ...
# ...

# %%
df.shape
# Out:
# (2312944, 24)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2312944 entries, 0 to 2312943
# Data columns (total 24 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   App Name           str
#  1   App Id             str
#  2   Category           str
#  3   Rating             float64
#  4   Rating Count       float64
#  5   Installs           str
#  6   Minimum Installs   float64
#  7   Maximum Installs   int64
#  8   Free               bool
#  9   Price              float64
#  10  Currency           str
#  11  Size               str
#  12  Minimum Android    str
#  13  Developer Id       str
#  14  Developer Website  str
#  15  Developer Email    str
#  16  Released           str
#  17  Last Updated       str
#  18  Content Rating     str
#  19  Privacy Policy     str
#  20  Ad Supported       bool
#  21  In App Purchases   bool
#  22  Editors Choice     bool
#  23  Scraped Time       str
# dtypes: bool(4), float64(4), int64(1), str(15)
# memory usage: 361.8 MB

# %% [markdown]
# # Key Observations
#
# Based on the initial inspection of the Google Play Store dataset, the following observations were made:
#
# 1. The dataset contains **2,312,944 records** and **24 columns**, making it a large-scale dataset suitable for production-style analytics.
#
# 2. The dataset contains a mix of **string, numeric, and boolean** data types.
#
# 3. Several columns that represent dates (such as **Released**, **Last Updated**, and **Scraped Time**) are currently stored as strings and will require conversion during preprocessing.
#
# 4. The **Installs** column is stored as text (for example, "10+", "1,000+") and will require cleaning before quantitative analysis.
#
# 5. The dataset includes multiple business dimensions such as Category, Content Rating, and Minimum Android that can be used for segmentation and comparison.
#
# 6. Monetization-related information is available through columns such as Free, Price, Ad Supported, and In App Purchases, enabling analysis of different business models.
#
# 7. Developer-related attributes such as Developer Id, Developer Website, and Developer Email can support ecosystem-level analysis.
#
# 8. Some columns are expected to contain missing values (for example, Developer Website and Privacy Policy), which will be investigated during the Data Quality Assessment phase.
#
# 9. The dataset appears comprehensive enough to answer business questions related to marketplace performance, user satisfaction, monetization, platform compatibility, and developer activity.
#
# 10. No data cleaning or transformations have been performed at this stage. The purpose of this notebook was only to inspect and understand the dataset before analysis begins.
